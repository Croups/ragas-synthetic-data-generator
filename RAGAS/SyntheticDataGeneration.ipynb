# %%
from langchain_openai import ChatOpenAI, OpenAIEmbeddings
from ragas.testset.generator import TestsetGenerator
from ragas.testset.evolutions import simple, reasoning, multi_context
from langchain_community.document_loaders import DirectoryLoader

# %%
import os
os.environ["OPENAI_API_KEY"] = "your-openai-key"

# %%
# Initialize OpenAI models (You need to have OpenAI API key)    
data_generation_model = ChatOpenAI(model='gpt-4o-mini')
critic_model = ChatOpenAI(model='gpt-4o')

# %%
embeddings = OpenAIEmbeddings(
    model="text-embedding-ada-002",  # Change with your model if needed
    chunk_size=1000
)

# %%
# Load documents
path = "Sample_Docs_Markdown/"
loader = DirectoryLoader(path, glob="**/*.md")
documents = loader.load()

# %%
generator = TestsetGenerator.from_langchain(
    data_generation_model,
    critic_model,
    embeddings
)

# %%
# Define distribution of question types, feel free to adjust the values as needed
distributions = {
    simple: 0.4,
    multi_context: 0.4,
    reasoning: 0.2
}

# %%
testset = generator.generate_with_langchain_docs(documents, 10, distributions)

test_df = testset.to_pandas()
print(test_df)
# Out:
# Filename and doc_id are the same for all nodes.
# Generating: 100%|██████████| 10/10 [01:47<00:00, 10.73s/it]
#                                             question  \
# 0  What advantages does the expert choice method ...
# 1  What evaluation benchmarks are used for assess...
# 2  What role do language modeling and machine tra...
# 3  What is the impact of fine-grained expert segm...
# 4  How does fine-grained expert segmentation impr...
# 5  How does supervised fine-tuning boost DeepSeek...
# 6  What eval strategies assess NLI performance in...
# 7  How does the binary tensor route tokens to exp...
# 8  What gains in capacity and efficiency come fro...
# 9  What gains does Switch Transformer have over T...
#
#                                             contexts  \
# 0  [ number of experts to 2 degrades the perplexi...
# 1  [ our MoE model to a larger scale with 16B tot...
# 2  [Outrageously Large Neural Networks: The Spars...
# 3  [ based on GShard. From Figure 3, we observe t...
# 4  [ based on GShard. From Figure 3, we observe t...
# 5  [, we take a broader set of open source models...
# 6  [ For both versions, we design a FLOP-matched ...
# 7  [ d model] router weights = mtf.Variable(shape...
# 8  [ The existing literature on conditional compu...
# 9  [T5 (Xue et al., 2020), a multilingual extensi...
#
#                                         ground_truth evolution_type  \
# 0  The expert choice method outperforms the top-2...         simple
# 1  The evaluation benchmarks used for assessing t...         simple
# 2  Language modeling and machine translation are ...         simple
# 3  The impact of fine-grained expert segmentation...         simple
# 4  Fine-grained expert segmentation improves mode...  multi_context
# 5  Supervised fine-tuning boosts DeepSeekMoE 16B'...  multi_context
# 6  The evaluation strategies that assess NLI perf...  multi_context
# 7  The binary dispatch tensor in Switch Transform...  multi_context
# 8  The Sparsely-Gated Mixture-of-Experts (MoE) ap...      reasoning
# 9  Switch Transformer shows significant gains ove...      reasoning
#
#                                             metadata  episode_done
# 0  [{'source': 'Sample_Docs_Markdown/2202.09368v2...          True
# 1  [{'source': 'Sample_Docs_Markdown/DeepSeekMoE_...          True
# 2  [{'source': 'Sample_Docs_Markdown/1701.06538v1...          True
# 3  [{'source': 'Sample_Docs_Markdown/DeepSeekMoE_...          True
# 4  [{'source': 'Sample_Docs_Markdown/DeepSeekMoE_...          True
# 5  [{'source': 'Sample_Docs_Markdown/DeepSeekMoE_...          True
# 6  [{'source': 'Sample_Docs_Markdown/switch_trans...          True
# 7  [{'source': 'Sample_Docs_Markdown/switch_trans...          True
# 8  [{'source': 'Sample_Docs_Markdown/1701.06538v1...          True
# 9  [{'source': 'Sample_Docs_Markdown/switch_trans...          True

# %%
test_df.to_csv('generated_testset.csv', index=False)

# %%
import pandas as pd

df = pd.read_csv('generated_testset.csv')
df
# Out:
#                                             question  \
# 0  What advantages does the expert choice method ...
# 1  What evaluation benchmarks are used for assess...
# 2  What role do language modeling and machine tra...
# 3  What is the impact of fine-grained expert segm...
# 4  How does fine-grained expert segmentation impr...
# 5  How does supervised fine-tuning boost DeepSeek...
# 6  What eval strategies assess NLI performance in...
# 7  How does the binary tensor route tokens to exp...
# 8  What gains in capacity and efficiency come fro...
# 9  What gains does Switch Transformer have over T...
#
#                                             contexts  \
# 0  [' number of experts to 2 degrades the perplex...
# 1  [' our MoE model to a larger scale with 16B to...
# 2  ['Outrageously Large Neural Networks: The Spar...
# 3  [' based on GShard. From Figure 3, we observe ...
# 4  [' based on GShard. From Figure 3, we observe ...
# 5  [', we take a broader set of open source model...
# 6  [" For both versions, we design a FLOP-matched...
# 7  [' d model] router weights = mtf.Variable(shap...
# 8  [' The existing literature on conditional comp...
# 9  ["T5 (Xue et al., 2020), a multilingual extens...
#
#                                         ground_truth evolution_type  \
# 0  The expert choice method outperforms the top-2...         simple
# 1  The evaluation benchmarks used for assessing t...         simple
# 2  Language modeling and machine translation are ...         simple
# 3  The impact of fine-grained expert segmentation...         simple
# 4  Fine-grained expert segmentation improves mode...  multi_context
# 5  Supervised fine-tuning boosts DeepSeekMoE 16B'...  multi_context
# 6  The evaluation strategies that assess NLI perf...  multi_context
# 7  The binary dispatch tensor in Switch Transform...  multi_context
# 8  The Sparsely-Gated Mixture-of-Experts (MoE) ap...      reasoning
# 9  Switch Transformer shows significant gains ove...      reasoning
#
#                                             metadata  episode_done
# 0  [{'source': 'Sample_Docs_Markdown/2202.09368v2...          True
# 1  [{'source': 'Sample_Docs_Markdown/DeepSeekMoE_...          True
# 2  [{'source': 'Sample_Docs_Markdown/1701.06538v1...          True
# 3  [{'source': 'Sample_Docs_Markdown/DeepSeekMoE_...          True
# 4  [{'source': 'Sample_Docs_Markdown/DeepSeekMoE_...          True
# 5  [{'source': 'Sample_Docs_Markdown/DeepSeekMoE_...          True
# 6  [{'source': 'Sample_Docs_Markdown/switch_trans...          True
# 7  [{'source': 'Sample_Docs_Markdown/switch_trans...          True
# 8  [{'source': 'Sample_Docs_Markdown/1701.06538v1...          True
# 9  [{'source': 'Sample_Docs_Markdown/switch_trans...          True
